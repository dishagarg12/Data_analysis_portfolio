# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Investigating the shape of Data.

# %%
df = pd.read_csv("flipkart_com-ecommerce_sample.csv")
df.head
# Out:
# <bound method NDFrame.head of                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
# 20000                               NaN                        NaN
# 20001                               NaN                        NaN
#
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# ...

# %%
df.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20002 entries, 0 to 20001
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  20000 non-null  object
#  1   crawl_timestamp          20000 non-null  object
#  2   product_url              20000 non-null  object
#  3   product_name             20000 non-null  object
#  4   product_category_tree    20000 non-null  object
#  5   pid                      20000 non-null  object
#  6   retail_price             19922 non-null  float64
#  7   discounted_price         19922 non-null  float64
#  8   image                    19997 non-null  object
#  9   is_FK_Advantage_product  20000 non-null  object
#  10  description              19998 non-null  object
#  11  product_rating           20000 non-null  object
#  12  overall_rating           20000 non-null  object
#  13  brand                    14136 non-null  object
# ...

# %% [markdown]
# ## checking last 5 rows

# %%
df.tail()
# Out:
#                                 uniq_id            crawl_timestamp  \
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
# 20000                               NaN                        NaN
# 20001                               NaN                        NaN
#
#                                              product_url  \
# 19997  http://www.flipkart.com/elite-collection-mediu...
# 19998  http://www.flipkart.com/elite-collection-mediu...
# 19999  http://www.flipkart.com/elite-collection-mediu...
# 20000                                                NaN
# 20001                                                NaN
#
#                                   product_name  \
# 19997  Elite Collection Medium Acrylic Sticker
# 19998  Elite Collection Medium Acrylic Sticker
# 19999  Elite Collection Medium Acrylic Sticker
# ...

# %%
#statistics value for this data
df.describe()
# Out:
#         retail_price  discounted_price
# count   19922.000000      19922.000000
# mean     2979.206104       1973.401767
# std      9009.639341       7333.586040
# min        35.000000         35.000000
# 25%       666.000000        350.000000
# 50%      1040.000000        550.000000
# 75%      1999.000000        999.000000
# max    571230.000000     571230.000000

# %%
#check the rows and columns of dataset
df.shape
# Out:
# (20002, 15)

# %%
# check each columns number of unique values 
df.nunique()
# Out:
# uniq_id                    20000
# crawl_timestamp              371
# product_url                20000
# product_name               12676
# product_category_tree       6466
# pid                        19998
# retail_price                2247
# discounted_price            2448
# image                      18589
# is_FK_Advantage_product        2
# description                17539
# product_rating                36
# overall_rating                36
# brand                       3499
# product_specifications     18825
# dtype: int64

# %% [markdown]
# ## calculate sum of null value for each column

# %%
df.isnull().sum()
# Out:
# uniq_id                       2
# crawl_timestamp               2
# product_url                   2
# product_name                  2
# product_category_tree         2
# pid                           2
# retail_price                 80
# discounted_price             80
# image                         5
# is_FK_Advantage_product       2
# description                   4
# product_rating                2
# overall_rating                2
# brand                      5866
# product_specifications       16
# dtype: int64

# %%
# Drop unuseful columns
df.drop(['uniq_id','overall_rating','image','product_specifications','description'],axis=1,inplace=True)

# %%
df.head(100)
# Out:
#               crawl_timestamp  \
# 0   2016-03-25 22:59:23 +0000
# 1   2016-03-25 22:59:23 +0000
# 2   2016-03-25 22:59:23 +0000
# 3   2016-03-25 22:59:23 +0000
# 4   2016-03-25 22:59:23 +0000
# ..                        ...
# 95  2015-12-04 07:25:36 +0000
# 96  2015-12-04 07:25:36 +0000
# 97  2015-12-04 07:25:36 +0000
# 98  2015-12-04 07:25:36 +0000
# 99  2015-12-04 07:25:36 +0000
#
#                                           product_url  \
# 0   http://www.flipkart.com/alisha-solid-women-s-c...
# 1   http://www.flipkart.com/fabhomedecor-fabric-do...
# 2   http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3   http://www.flipkart.com/alisha-solid-women-s-c...
# 4   http://www.flipkart.com/sicons-all-purpose-arn...
# ..                                                ...
# 95  http://www.flipkart.com/reckler-slim-fit-men-s...
# 96  http://www.flipkart.com/quechua-arpenaz-novadr...
# 97  http://www.flipkart.com/colat-colat-mw20-sheen...
# ...

# %%
df.fillna(df.mean(),inplace  = True)

# %%
df.tail()
# Out:
#                  crawl_timestamp  \
# 19997  2015-12-01 10:15:43 +0000
# 19998  2015-12-01 10:15:43 +0000
# 19999  2015-12-01 10:15:43 +0000
# 20000                        NaN
# 20001                        NaN
#
#                                              product_url  \
# 19997  http://www.flipkart.com/elite-collection-mediu...
# 19998  http://www.flipkart.com/elite-collection-mediu...
# 19999  http://www.flipkart.com/elite-collection-mediu...
# 20000                                                NaN
# 20001                                                NaN
#
#                                   product_name  \
# 19997  Elite Collection Medium Acrylic Sticker
# 19998  Elite Collection Medium Acrylic Sticker
# 19999  Elite Collection Medium Acrylic Sticker
# 20000                                      NaN
# 20001                                      NaN
#
#                                    product_category_tree               pid  \
# ...

# %%
# calculate sum of null value for each coloumn
df.isnull().sum()
# Out:
# crawl_timestamp               2
# product_url                   2
# product_name                  2
# product_category_tree         2
# pid                           2
# retail_price                  0
# discounted_price              0
# is_FK_Advantage_product       0
# product_rating                2
# brand                      5866
# dtype: int64

# %%
# fill NaN value with No brand in brand column 
df["brand"].fillna("No brand", inplace = True)

# %%
df.isnull().sum()
# Out:
# crawl_timestamp            2
# product_url                2
# product_name               2
# product_category_tree      2
# pid                        2
# retail_price               0
# discounted_price           0
# is_FK_Advantage_product    0
# product_rating             2
# brand                      0
# dtype: int64

# %%
# Drop null values for each coloumn containing null values
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# crawl_timestamp            0
# product_url                0
# product_name               0
# product_category_tree      0
# pid                        0
# retail_price               0
# discounted_price           0
# is_FK_Advantage_product    0
# product_rating             0
# brand                      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 0 to 19999
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   crawl_timestamp          20000 non-null  object
#  1   product_url              20000 non-null  object
#  2   product_name             20000 non-null  object
#  3   product_category_tree    20000 non-null  object
#  4   pid                      20000 non-null  object
#  5   retail_price             20000 non-null  float64
#  6   discounted_price         20000 non-null  float64
#  7   is_FK_Advantage_product  20000 non-null  object
#  8   product_rating           20000 non-null  object
#  9   brand                    20000 non-null  object
# dtypes: float64(2), object(8)
# memory usage: 1.7+ MB

# %%
df.describe()
# Out:
#         retail_price  discounted_price
# count   20000.000000      20000.000000
# mean     2979.206104       1973.401767
# std      8992.052501       7319.270861
# min        35.000000         35.000000
# 25%       675.000000        350.000000
# 50%      1049.000000        550.000000
# 75%      1999.000000       1000.000000
# max    571230.000000     571230.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# visualize each variable 
df.hist(figsize =(6,6))
# Out:
# array([[<AxesSubplot:title={'center':'retail_price'}>,
#         <AxesSubplot:title={'center':'discounted_price'}>]], dtype=object)

# %%
# top 10 products 
df["product_name"].value_counts()[:10].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
# top 6 brands with percentage
df["brand"].value_counts()[1:7].plot(kind='pie',autopct='%1.0f%%',figsize =(9,9))
# Out:
# <AxesSubplot:ylabel='brand'>
